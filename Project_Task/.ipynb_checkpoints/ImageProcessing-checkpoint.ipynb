# %%
# !pip install slideio
# Out:
# Collecting slideio
#   Downloading slideio-1.0.3-cp38-cp38-win_amd64.whl (13.5 MB)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from slideio) (1.23.3)
# Installing collected packages: slideio
# Successfully installed slideio-1.0.3

# %%
import slideio
slide = slideio.open_slide("./Normal_Lymphnode.svs", 'SVS')
num_scenes = slide.num_scenes
for index in range(0, num_scenes):
    print(slide.get_scene(index).name)
print(num_scenes)
# Out:
# Image
# 1

# %%
import tifffile as tiff
#from patchify import patchify
from matplotlib import pyplot as plt
import numpy as np


import slideio
slide = slideio.open_slide("./Normal_Lymphnode.svs", 'SVS')
num_scenes = slide.num_scenes
scene = slide.get_scene(0)

scene.rect
# Out:
# (0, 0, 35817, 38693)

# %%
import math
width = scene.rect[2]
height = scene.rect[3]

width = math.floor(width / 2500) * 2500
height = math.floor(height / 2500) * 2500


for i in range(0,height, 2500):
    for j in range(0, width, 2500):
        image1 = scene.read_block((i, j, 2500, 2500), size = (500, 0))
        im = Image.fromarray(image1)
        im.save(f"./images/{i}_{j}.jpeg")
# Out:
# 210

# %%
for i in range(0,height, 2500):
    for j in range(0, width, 2500):
        import os
        s = os.path.getsize(f"./images/{i}_{j}.jpeg")
        print(s)
        break
    break
# Out:
# 5131

# %%
print(num_scenes, scene.name, scene.rect, scene.num_channels)


slide = slideio.open_slide("./Normal_Lymphnode.svs", "SVS")
raw_string = slide.raw_metadata
raw_string.split("|")


image = scene.read_block(size=(500, 0))
plt.imshow(image)
image.shape
# Out:
# 1 Image (0, 0, 35817, 38693) 3
# (540, 500, 3)

# %%
from PIL import Image


image1 = scene.read_block((15000, 15000, 1000, 1000))
plt.imshow(image)
im = Image.fromarray(image1)
im.save("your_file.jpeg")

# %%
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
